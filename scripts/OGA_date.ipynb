# %%
import pandas as pd
import lxml

# %%
pd.read_xml("../data/sources/OGA/chronology_greek_works_plus_date_label.xml")
# Out:
#         id            urn_cts  \
# 0        1     ogl0001.ogl001
# 1        2   stoa0033a.tlg028
# 2        3   stoa0033a.tlg043
# 3        4   stoa0121.stoa001
# 4        5  stoa0146d.stoa001
# ...    ...                ...
# 1906  1913     tlg2934.tlg066
# 1907  1914     tlg4029.tlg001
# 1908  1915     tlg4029.tlg002
# 1909  1916     tlg4091.tlg001
# 1910  1917     tlg9006.tlg016
#
#                                            title_labels  \
# 0                       De Epistola Pinyti ad Dionysium
# 1                                              De mundo
# 2                                            De spiritu
# 3                          Breviarium historiae romanae
# 4                                         Acta Archelai
# ...                                                 ...
# 1906                            Vita Barlaam et Joasaph
# 1907                                          De Bellis
# 1908                                    Historia Arcana
# ...
